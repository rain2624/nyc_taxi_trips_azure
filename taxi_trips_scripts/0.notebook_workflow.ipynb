# %%
v_results = dbutils.notebook.run("ingestion_scripts/1.ingesting_data",0, {"p_file_date":"2025-09-01"})

# %%
v_results

# %%
v_results = dbutils.notebook.run("ingestion_scripts/2.data_transformation",0, {"p_file_date":"2025-09-01"})

# %%
v_results

# %%
v_results = dbutils.notebook.run("data_marts/1.taxi_trips_merge_table",0, {"p_file_date":"2025-09-01"})

# %%
v_results

# %%
v_results = dbutils.notebook.run("data_marts/2.taxi_trips_data_marts",0, {"p_file_date":"2025-09-01"})

# %%
v_results
